# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('OulierRemoved_All_Parameter_Data.csv')
# df = df.drop(['SUPPY_FAN_SPEED', 'EXHAUST_FANSPEED'], axis = 1)
s = df.corr()
sns.heatmap(s)
# Out:
# <AxesSubplot:>

# %%
df = df.drop('MOISTURE_CONTENT ', axis = 1)

# %%
sns.heatmap(df.corr())
plt.savefig('heatmap.pdf', dpi = 300)
